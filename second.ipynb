# %% [markdown]
# # Imports

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488491 sha256=a0eee9694ad31e11cff22126715a2dcc3c6e7c89670cc186ddbb87fee7b625f9
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, explode, expr

# %% [markdown]
# # Configs

# %%
# Initializing SparkSession
spark = SparkSession.builder.appName('Case Oper').getOrCreate()

# Defining the path to the JSON file
path_json = '/content/drive/MyDrive/Colab Notebooks/teste-tecnico-main/base_desafio.json'
path_output = '/content/drive/MyDrive/Colab Notebooks/teste-tecnico-main/outputs/second_question'

# %%
# Reading JSON file into a Spark DataFrame, allowing multiline JSON objects
df = spark.read.option("multiline","true") .json(path_json)

# %% [markdown]
# # Second question

# %%
# Selecting and exploding the 'items' array from the DataFrame 'df'
items_df = df.select(explode("resource.items").alias("item"))

# %%
# Selecting specific columns from the 'items_df' DataFrame and renaming them to follow snake_case naming convention

items_df = items_df.select(
    col("item.name").alias("name"),
    col("item.lastMessageDate").alias("last_message_date"),
    col("item.identity").alias("identity"),
    col("item.phoneNumber").alias("phone_number"),
    col("item.source").alias("source"),
    col("item.extras.protocoloWci").alias("extras_protocolo_wci"),
    col("item.extras.UtmCampaign").alias("extras_utm_campaign"),
    col("item.extras.applicationIdentifier").alias("extras_application_identifier"),
    col("item.extras.primeiraMensagem").alias("extras_primeira_mensagem"),
    col("item.extras.produto").alias("extras_produto"),
    col("item.extras.`1. Boas vindas`").alias("extras_etapa_boas_vindas"),
    col("item.extras.prioridade").alias("extras_prioridade"),
    col("item.extras.`2. Cep`").alias("extras_etapa_cep"),
    col("item.extras.canal").alias("extras_canal"),
    col("item.extras.`99. Abandono`").alias("extras_etapa_abandono")
)

# %%
# Converting columns starting with 'extras_etapa_' to boolean type in the DataFrame 'items_df'
for column in items_df.columns:
    if column.startswith("extras_etapa_"):
        items_df = items_df.withColumn(column, expr(f"cast({column} as boolean)"))

# %%
#Only to show
items_df.show(truncate=False)
# Out:
# +---------+------------------------+---------------------------+---------------------+----------+---------------------+---------------------+-----------------------------+----------------------------------------------------------------------------+--------------+------------------------+-----------------+----------------+-------------+---------------------+
# |name     |last_message_date       |identity                   |phone_number         |source    |extras_protocolo_wci |extras_utm_campaign  |extras_application_identifier|extras_primeira_mensagem                                                    |extras_produto|extras_etapa_boas_vindas|extras_prioridade|extras_etapa_cep|extras_canal |extras_etapa_abandono|
# +---------+------------------------+---------------------------+---------------------+----------+---------------------+---------------------+-----------------------------+----------------------------------------------------------------------------+--------------+------------------------+-----------------+----------------+-------------+---------------------+
# |Wilfredo |2024-06-19T18:07:26.256Z|781.361.413-88@done.msg.net|1-232-927-2293 x508  |amplitudo |C_0UpkajtK1A-Byeq37cg|irRzzChMpWjKN2HiGtThJ|F_eBenTe3hKuuokkfHqS6        |Utrimque celebrer cicuta aliquam.                                           |demergo       |true                    |2609348421353472 |true            |abeo         |true                 |
# |Martine  |2024-06-19T15:46:13.140Z|298.983.057-50@done.msg.net|233-257-4826         |facilis   |S5Wk_FE9QpwWMv4cnXdkI|VfkyKRF_Lktbd6LW74BvZ|6UJk71Zw1p2EgMUoFq-hA        |Laboriosam basium velut.                                                    |benigne       |true                    |6399185265885184 |true            |demitto      |true                 |
# |Nikita   |2024-06-19T15:40:50.638Z|406.972.733-91@done.msg.net|1-422-844-7024 x8060 |quo       |Tk9NbMz2GjqS4nyIXb5tj|hC8BFoEhWOO0CahdqsLAu|bOp-LkLrqR4BhMO-bJq3-        |Cribro circumvenio vapulus.                                                 |victus        |true                    |6210810531545088 |true            |comis        |true                 |
# |Dan      |2024-06-19T02:43:48.855Z|755.617.160-87@done.msg.net|615.874.7644 x5687   |argumentum|kuQ2remNUMNp6y06AFdfi|TnpdQfVJBIkMadDnPG0u2|oUkyJatk1xEUbksMXkEQp        |Venia clementia una ter aestas.                                             |confugo       |true                    |5927832049942528 |true            |adinventitias|true                 |
# |Trudie   |2024-06-19T08:18:30.431Z|889.928.553-56@done.msg.net|1-600-635-1325 x3453 |calculus  |vPx_TRkByEPb9QKDdI6h9|5H87VD_Cc5D0J0Z_xcvXq|5FpYvgnpt_cFacnalmS05        |Vulgus quas caelestis cilicium coma admiratio depopulo stabilis temperantia.|trucido       |true                    |3578143206014976 |true            |aliquam      |true                 |
# |Estefania|2024-06-19T09:35:57.243Z|265.154.202-05@done.msg.net|563-862-9587 x6952   |adnuo     |GJpYmEYC5RRfTt-vhdiVN|vb1MU4cM7grzKmrESAldQ|LotwwvSYB4YNhhKINxfqA        |Caritas depereo aliqua venia iure.                                          |asporto       |true                    |6251138875654144 |true            |tametsi      |true                 |
# |Arnoldo  |2024-06-19T16:04:03.080Z|192.472.587-38@done.msg.net|414-596-9406         |quos      |Ej3hZ-f4Yv0kLpEc3rB2K|NCJWOPfN4zN0JacINsbci|wPIta9vxQvhykhh5OBR97        |Defleo quasi ad officiis degero adeptio.                                    |demum         |true                    |4614983786692608 |true            |valens       |true                 |
# |Chaya    |2024-06-19T02:06:53.844Z|856.576.911-94@done.msg.net|1-914-269-2601       |undique   |g9lB2aDN9jrzJL33svNXN|ZwXvOa_GuFu9kIN1NMJx7|HtHm5f4Ut9zHihGbXcfTo        |Curriculum voveo commodi deleo amitto adulatio.                             |vero          |true                    |288611629006848  |true            |ea           |true                 |
# |Reynold  |2024-06-19T14:30:13.472Z|555.532.522-02@done.msg.net|1-466-677-5625 x709  |desipio   |4DeOJ4IM8l4C25b8Opq4Y|fjAlYT1q_yRH36GKYHyHd|JRvjQIowrWQSEpTuC8ysN        |Deleniti nobis tamisium succurro aggredior clarus quod reiciendis.          |coadunatio    |true                    |864392746893312  |true            |esse         |true                 |
# |Joan     |2024-06-19T21:13:16.834Z|720.898.351-92@done.msg.net|626.859.2368         |timidus   |w5sfZ1oLtBDvpUIxiBHwP|tM_HDpIbAHd6zpeQmjfv5|emuxNHLPUDK7iUZigvt9W        |Substantia trans demonstro dolorum absum voluptates adimpleo deputo.        |arguo         |true                    |692669896458240  |true            |conor        |NULL                 |
# |Enrique  |2024-06-19T03:28:39.481Z|060.838.972-25@done.msg.net|1-532-310-8381 x84960|volaticus |9TvAai1o0fwW2CAxLiRFo|snz6jZhw4721QQFe2M8sI|FcU6W1j_zS-ItW4-ADSE-        |Theologus corporis pecus ullam degenero itaque demulceo aliqua.             |altus         |true                    |1625638947520512 |true            |audax        |true                 |
# |Elenor   |2024-06-19T17:30:58.924Z|588.443.201-94@done.msg.net|(751) 872-7896 x6367 |totidem   |r-wk4_Nx12kCYRYsGrkDu|IyuPWUB2RgbhokbhUlwA_|mOpKQcAQj88D8GETQglvh        |Dolorem quis aveho tempus cumque coma benevolentia.                         |defaeco       |true                    |7154008426807296 |true            |adipiscor    |NULL                 |
# |Dalton   |2024-06-19T06:49:05.824Z|383.777.826-86@done.msg.net|501.459.8706 x98821  |hic       |BP6A27hBE5wyB7B_MPtkZ|8y-RjEdVahjrNVrTgCL44|NqAxdbpHy9AT3BGeu2nsl        |Custodia velum absconditus sum arx tempore absens aptus abstergo.           |caelestis     |true                    |3734600750727168 |true            |auxilium     |NULL                 |
# |Ismael   |2024-06-19T14:01:47.498Z|621.871.550-22@done.msg.net|586-498-2543 x299    |venio     |cRHrkAVmdNRLQ6f4nG3EW|8tSMgb73zGAX1nIq52YEg|mgwEGzCvgkKtUpdR9xnfZ        |Coaegresco exercitationem degusto tumultus terreo dedecor virgo.            |creta         |true                    |1529390743683072 |true            |totam        |true                 |
# |Domenico |2024-06-18T23:37:11.572Z|863.171.868-34@done.msg.net|1-781-547-1322 x7257 |territo   |-0GBi9UfvEURXqHS2-V_k|iU9gjL4LUdggmqUzTo1r4|MopFLTlos7MngzJZxsCSd        |Brevis desolo sol error cupiditas vere.                                     |cum           |true                    |1671535819489280 |true            |ratione      |true                 |
# |Jasmin   |2024-06-19T14:45:37.284Z|672.323.961-40@done.msg.net|(235) 481-6234 x16306|repellat  |6rsnQazeyocZv6DPbUrEd|fzptPvxlW7dEDdKzP_1fS|dD6xKJusgsd-AaGyTAhW6        |Provident adeo est timor ademptio taceo pel repellat.                       |cura          |true                    |529230475558912  |true            |vallum       |NULL                 |
# |Valentine|2024-06-19T10:27:19.208Z|160.607.589-26@done.msg.net|977.796.2579 x4347   |bestia    |BApl0WmULota6kn0b_z83|sPNQSpzjsAEKXaQ43YIth|o9tVrK14u3UHAL8U18gLD        |Via subiungo reprehenderit labore at bellum.                                |valeo         |true                    |4252788924088320 |true            |venustas     |NULL                 |
# |Clare    |2024-06-18T23:08:02.931Z|301.514.330-52@done.msg.net|(542) 598-8868 x617  |ea        |_OrSh80Bn8V1LWrUdyJC8|FDOrOdjSyv6Nonxc4O7cT|OdlEyZIE7sxaQmmwVTJr9        |Comparo angulus decet.                                                      |molestias     |true                    |8363307832442880 |true            |suus         |true                 |
# |Filiberto|2024-06-19T17:58:20.398Z|000.405.778-98@done.msg.net|1-977-558-7812 x006  |vester    |oAOUN0LH8I3KJkZYJhMDf|nXlS4X5hJjq4hvBy8tfqI|xSTlrRXN3bs0j4C2nrFs0        |Vindico dignissimos decens.                                                 |amiculum      |true                    |1747548815491072 |true            |asporto      |true                 |
# |Edmond   |2024-06-19T16:35:20.333Z|534.008.742-47@done.msg.net|(439) 960-6267 x5762 |unde      |XCy6zOW99EzjwOB5WZ5SL|-PWCFem1LI_uhOSRwhTJl|Jz71CLuct-N2eP1gCLBGz        |Arto aranea ventus accommodo.                                               |tripudio      |true                    |1008376790122496 |true            |valeo        |true                 |
# +---------+------------------------+---------------------------+---------------------+----------+---------------------+---------------------+-----------------------------+----------------------------------------------------------------------------+--------------+------------------------+-----------------+----------------+-------------+---------------------+
# only showing top 20 rows

# %%
#Only to show
items_df.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- last_message_date: string (nullable = true)
#  |-- identity: string (nullable = true)
#  |-- phone_number: string (nullable = true)
#  |-- source: string (nullable = true)
#  |-- extras_protocolo_wci: string (nullable = true)
#  |-- extras_utm_campaign: string (nullable = true)
#  |-- extras_application_identifier: string (nullable = true)
#  |-- extras_primeira_mensagem: string (nullable = true)
#  |-- extras_produto: string (nullable = true)
#  |-- extras_etapa_boas_vindas: boolean (nullable = true)
#  |-- extras_prioridade: long (nullable = true)
#  |-- extras_etapa_cep: boolean (nullable = true)
#  |-- extras_canal: string (nullable = true)
#  |-- extras_etapa_abandono: boolean (nullable = true)

# %%
items_df.repartition(1).write.mode("overwrite").parquet(f"{path_output}/items_df.parquet")

# %% [markdown]
# # Additional code

# %%
nulos_por_coluna = items_df.select([col(c).isNull().alias(c) for c in items_df.columns])

# %%
nulos_por_coluna.show()
# Out:
# +-----+-----------------+--------+------------+------+--------------------+-------------------+-----------------------------+------------------------+--------------+------------------------+-----------------+----------------+------------+---------------------+
# | name|last_message_date|identity|phone_number|source|extras_protocolo_wci|extras_utm_campaign|extras_application_identifier|extras_primeira_mensagem|extras_produto|extras_etapa_boas_vindas|extras_prioridade|extras_etapa_cep|extras_canal|extras_etapa_abandono|
# +-----+-----------------+--------+------------+------+--------------------+-------------------+-----------------------------+------------------------+--------------+------------------------+-----------------+----------------+------------+---------------------+
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                false|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                false|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                false|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                false|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                false|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                false|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                false|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                false|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                false|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                 true|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                false|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                 true|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                 true|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                false|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                false|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                 true|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                 true|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                false|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                false|
# |false|            false|   false|       false| false|               false|              false|                        false|                   false|         false|                   false|            false|           false|       false|                false|
# +-----+-----------------+--------+------------+------+--------------------+-------------------+-----------------------------+------------------------+--------------+------------------------+-----------------+----------------+------------+---------------------+
# only showing top 20 rows

# %%
# Get list of columns in the DataFrame
columns = items_df.columns

# Loop through columns and count nulls
for column in columns:
    null_count = items_df.where(col(column).isNull()).count()

    # Print the count of null values for each column
    print(f"Column '{column}' has {null_count} null values.")

# Alternatively, collect counts into a dictionary
null_counts = {column: items_df.where(col(column).isNull()).count() for column in columns}
print(null_counts)
# Out:
# Column 'name' has 4 null values.
# Column 'last_message_date' has 0 null values.
# Column 'identity' has 0 null values.
# Column 'phone_number' has 3 null values.
# Column 'source' has 6 null values.
# Column 'extras_protocolo_wci' has 4 null values.
# Column 'extras_utm_campaign' has 4 null values.
# Column 'extras_application_identifier' has 4 null values.
# Column 'extras_primeira_mensagem' has 3 null values.
# Column 'extras_produto' has 4 null values.
# Column 'extras_etapa_boas_vindas' has 4 null values.
# Column 'extras_prioridade' has 4 null values.
# Column 'extras_etapa_cep' has 4 null values.
# Column 'extras_canal' has 4 null values.
# Column 'extras_etapa_abandono' has 576 null values.
# {'name': 4, 'last_message_date': 0, 'identity': 0, 'phone_number': 3, 'source': 6, 'extras_protocolo_wci': 4, 'extras_utm_campaign': 4, 'extras_application_identifier': 4, 'extras_primeira_mensagem': 3, 'extras_produto': 4, 'extras_etapa_boas_vindas': 4, 'extras_prioridade': 4, 'extras_etapa_cep': 4, 'extras_canal': 4, 'extras_etapa_abandono': 576}

# %%
# replace null values ​​with "N/A"
items_df.na.fill('N/A')
# Out:
# DataFrame[name: string, last_message_date: string, identity: string, phone_number: string, source: string, extras_protocolo_wci: string, extras_utm_campaign: string, extras_application_identifier: string, extras_primeira_mensagem: string, extras_produto: string, extras_etapa_boas_vindas: boolean, extras_prioridade: bigint, extras_etapa_cep: boolean, extras_canal: string, extras_etapa_abandono: boolean]
